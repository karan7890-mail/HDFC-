# %%
import pandas as pd

# %%
Stockdata =pd.read_csv("C:\\Users\\Admin\\Desktop\\HDB\\HDB.csv")

# %%
print(Stockdata)
# Out:
#           Date       Open       High        Low      Close  Adj Close   Volume
# 0   2023-01-20  69.989998  70.489998  68.779999  70.489998  70.489998  1253200
# 1   2023-01-23  70.320000  70.889999  70.050003  70.750000  70.750000  1188000
# 2   2023-01-24  71.000000  71.760002  70.559998  71.440002  71.440002  1209900
# 3   2023-01-25  69.570000  69.660004  66.930000  66.930000  66.930000  2429100
# 4   2023-01-26  67.410004  68.050003  67.050003  68.010002  68.010002  1394300
# ..         ...        ...        ...        ...        ...        ...      ...
# 57  2023-04-13  70.220001  70.220001  68.279999  69.459999  69.459999  1121800
# 58  2023-04-14  69.400002  70.470001  69.389999  70.430000  70.430000  1778800
# 59  2023-04-17  68.739998  69.190002  68.059998  68.680000  68.680000  1688700
# 60  2023-04-18  68.910004  69.160004  68.449997  68.930000  68.930000  2881700
# 61  2023-04-19  69.339996  70.180000  68.790001  69.959999  69.959999  1691400
#
# [62 rows x 7 columns]

# %%
Stockdata.tail(n=5)
# Out:
#           Date       Open       High        Low      Close  Adj Close   Volume
# 57  2023-04-13  70.220001  70.220001  68.279999  69.459999  69.459999  1121800
# 58  2023-04-14  69.400002  70.470001  69.389999  70.430000  70.430000  1778800
# 59  2023-04-17  68.739998  69.190002  68.059998  68.680000  68.680000  1688700
# 60  2023-04-18  68.910004  69.160004  68.449997  68.930000  68.930000  2881700
# 61  2023-04-19  69.339996  70.180000  68.790001  69.959999  69.959999  1691400

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
Stockdata =pd.read_csv("C:\\Users\\Admin\\Desktop\\HDB\\HDB.csv")

# %%
import matplotlib.pyplot as plt
import pandas as pd


Stockdata = pd.DataFrame({'Date': ['2023-04-13', '2023-04-14', '2023-04-17', '2023-04-18', '2023-04-19'],
                   'Open': [70.220001, 69.400002, 68.739998, 68.910004, 69.339996],
                   'High': [70.220001, 70.470001, 69.190002, 69.160004, 70.180000],
                   'Low': [68.279999, 69.389999, 68.059998, 68.449997, 68.790001],
                   'Close': [69.459999, 70.430000, 68.680000, 68.930000, 69.959999],
                   'Adj Close': [69.459999, 70.430000, 68.680000, 68.930000, 69.959999],
                   'Volume': [1121800, 1778800, 1688700, 2881700, 1691400]})

plt.plot(Stockdata['Date'], Stockdata['Close'])

plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock Market Data')


plt.show()

# %%
stock_data = {'Date': ['2021-01-04', '2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08'],
              'Open': [70.220001, 69.400002, 68.739998, 68.910004, 69.339996],
              'High': [70.220001, 70.470001, 69.190002, 69.160004, 70.180000],
              'Low': [68.279999, 69.389999, 68.059998, 68.449997, 68.790001],
              'Close': [69.459999, 70.430000, 68.680000, 68.930000, 69.959999],
              'Adj Close': [69.459999, 70.430000, 68.680000, 68.930000, 69.959999],
              'Volume': [1121800, 1778800, 1688700, 2881700, 1691400]}

close_prices = stock_data['Close']


average_close_price = sum(close_prices) / len(close_prices)


print(f"The average of the 'Close' prices is: {average_close_price}")
# Out:
# The average of the 'Close' prices is: 69.4919996

# %%
Stockdata.tail()
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume
# 0  2023-04-13  70.220001  70.220001  68.279999  69.459999  69.459999  1121800  \
# 1  2023-04-14  69.400002  70.470001  69.389999  70.430000  70.430000  1778800
# 2  2023-04-17  68.739998  69.190002  68.059998  68.680000  68.680000  1688700
# 3  2023-04-18  68.910004  69.160004  68.449997  68.930000  68.930000  2881700
# 4  2023-04-19  69.339996  70.180000  68.790001  69.959999  69.959999  1691400
#
#    ATR
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
import matplotlib.pyplot as plt

# Input data
dates = ['20-01-2023', '23-01-2023', '24-01-2023', '25-01-2023', '26-01-2023', 
         '27-01-2023', '30-01-2023', '31-01-2023', '01-02-2023', '02-02-2023', '03-02-2023']
closing_prices = [70.489998, 70.75, 71.440002, 66.93, 68.010002, 65.769997, 
                  66.0, 67.360001, 64.68, 67.099998, 67.480003]

# Create bar chart
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(dates, closing_prices)

# Add labels and title
ax.set_xlabel('Date')
ax.set_ylabel('Closing Price ($)')
ax.set_title('Closing Prices for January 2023')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the data
dates = ['20-01-2023', '23-01-2023', '24-01-2023', '25-01-2023', '26-01-2023', '27-01-2023', '30-01-2023', '31-01-2023', '01-02-2023', '02-02-2023', '03-02-2023']
opens = [69.989998, 70.32, 71, 69.57, 67.410004, 66.779999, 66.099998, 65.879997, 67.650002, 65.269997, 67.230003]
closes = [70.489998, 70.75, 71.440002, 66.93, 68.010002, 65.769997, 66, 67.360001, 64.68, 67.099998, 67.480003]

# Create the scatter chart
plt.scatter(dates, opens, label='Open', color='red')
plt.scatter(dates, closes, label='Close', color='blue')
plt.xticks(rotation=45)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock Prices')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the data
dates = ['20-01-2023', '23-01-2023', '24-01-2023', '25-01-2023', '26-01-2023', '27-01-2023', '30-01-2023', '31-01-2023', '01-02-2023', '02-02-2023', '03-02-2023']
opens = [69.989998, 70.32, 71, 69.57, 67.410004, 66.779999, 66.099998, 65.879997, 67.650002, 65.269997, 67.230003]
closes = [70.489998, 70.75, 71.440002, 66.93, 68.010002, 65.769997, 66, 67.360001, 64.68, 67.099998, 67.480003]
volumes = [1253200, 1188000, 1209900, 2429100, 1394300, 2746900, 2034900, 1584800, 3016400, 1995900, 1901700]

# Create the scatter chart
plt.scatter(dates, opens, label='Open', marker='o')
plt.scatter(dates, closes, label='Close', marker='o')
plt.scatter(dates, volumes, label='Volume', marker='o')

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Stock Data')

# Add legend and show the chart
plt.legend()
plt.show()
